# %%
import os
import argparse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import scipy.optimize as optimize
from findiff import FinDiff, coefficients, Coefficient

# %%
# SET THE WORKING DIRECTORY
CWD = '/Users/miguel/Documents/Internship_CENTURI'
os.chdir(CWD)

# %%
## DEFINES WORKING CONSTANTS
#FILENAME = args.filename
FILENAME = 'gc_wt.csv'
SAVE_FN = FILENAME.strip().split('.')[0]
START = 105 # Start of the linear portion of the graph
ALPH_DICT = {'A':0, 'B':1, 'C':2, 'D':3, 'E':3, 'F':5, 'G':6, 'H':7}

# %%
FILE_PATH = os.path.join(os.getcwd(), "data", FILENAME)
df = pd.read_csv(FILE_PATH)

# %%
def logistic(x, K, A, C, Q, B, nu):
    '''
        K : carrying capacity
        A : left asymptote
        
    '''
    logistic_den = np.float_power(C + Q * np.exp(-B * x), 1 / nu)
    logistic = (K - A)/ logistic_den + A
    return logistic

# %%
def log_lin(x, K, Q, B, nu, m, b):
    '''
        K : carrying capacity
        A : left asymptote
        
    '''
    logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
    logistic = K / logistic_den 
    linear = m * x +  b
    return logistic + linear

# %%
X = np.arange(df.shape[0])
y = df['A5'].values
p0 = np.array([1, 0.5, 2, 2e-1, 3e-3, 0], dtype=np.longdouble)
params, cv = optimize.curve_fit(log_lin, X, y, p0, maxfev = 1000000)
# Out:
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in exp
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: invalid value encountered in float_power
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:8: RuntimeWarning: divide by zero encountered in divide
#   logistic = K / logistic_den
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in multiply
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:8: RuntimeWarning: overflow encountered in divide
#   logistic = K / logistic_den
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in float_power
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)

# %%
plt.figure(figsize = (10, 8))
plt.plot(log_lin(X, *params))
plt.plot(y, 'x-', alpha = 0.5)
# Out:
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in float_power
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)

# %% [markdown]
# def logistic(x, K, A, C, Q, B, nu):

# %% [markdown]
# Let's fit a simple logistic curve to first part of the data to get an estimate of the replication rates

# %%
def simple_logistic(x, K,  B, nu):
    '''
        K : carrying capacity
        B : growth rate
        
    '''
    logistic_den = np.float_power(1 + np.exp(-B * x), 1 / nu)
    logistic = K / logistic_den
    return logistic

# %%
X = np.arange(df.shape[0])
y = df['G2'].values
mean_y = df[df.columns[1:-1]].mean(axis = 1).values
threshold = 100
p0 = (0.4, 2, 2)

# %%
#simple_log_params, cv = optimize.curve_fit(simple_logistic, X[:threshold], y[:threshold], p0, maxfev = 100000)
simple_log_params, cv = optimize.curve_fit(simple_logistic, X[:threshold], mean_y[:threshold], p0, maxfev = 100000)
# Out:
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1783425730.py:8: RuntimeWarning: divide by zero encountered in divide
#   logistic = K / logistic_den
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1783425730.py:8: RuntimeWarning: overflow encountered in divide
#   logistic = K / logistic_den
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1783425730.py:7: RuntimeWarning: overflow encountered in exp
#   logistic_den = np.float_power(1 + np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1783425730.py:7: RuntimeWarning: overflow encountered in float_power
#   logistic_den = np.float_power(1 + np.exp(-B * x), 1 / nu)

# %%
simple_log_params
# Out:
# array([0.5518465 , 0.06381521, 0.01729553])

# %%
plt.figure(figsize = (10, 6))
plt.plot(X[:threshold], simple_logistic(X[:threshold], *simple_log_params))
#plt.plot(y[:threshold], marker = 'x')
plt.plot(mean_y[:threshold], marker = 'x')

# %%
plt.figure(figsize = (10,6))
for i in df.columns[1:-1]:
    c = 0
    #plt.plot(df[i][:threshold], label = i)
    #plt.plot(df[i], marker = 'x', alpha = 0.5)
#plt.xticks(np.arange(0,501,100),list(df['Time'].values[np.arange(0,501,100)]))

plt.plot(df[df.columns[1:-1]].mean(axis = 1)[:threshold], '--',label = "Mean")
plt.xlabel('Time(HH:MM:SS)');
plt.ylabel('OD');
plt.title('Growth Curves');
plt.legend();

# %%
def fit_lin_log(data):
    params = {}
    # Array representing time
    X = np.arange(df.shape[0])
    for i in df.columns.values[1:-1]:
        # Temporary dictionary to store fit parameters
        temp_params = ["K", "Q", "B", "nu", "m", "b"]
        
        # Array with the OD values
        y = df[i].values
        
        # Initial position for optimization, initially using the same for all columns
        # Might be column dependant
        p0 = np.array([1, 0.5, 2, 2e-1, 3e-3, 0], dtype=np.longdouble)
        temp, cv = optimize.curve_fit(log_lin, X, y, p0, maxfev = 1000000)
        params[i] = dict(zip(["K", "Q", "B", "nu", "m", "b"], temp))
    
    return params

# %%
def plot_fit(df, params, func):
    nrows = len(params) // 2
    fig, ax = plt.subplots(nrows = nrows, ncols = 2, figsize = (20, 6 * nrows), sharex = False)
    for i, axes in enumerate(ax):
        col = list(params.keys())[i]
        axes.plot(func(df[col].values, *list(params[col].values)))
        axes.plot(df[col], 'x-', alpha=0)
        axes.set_xlabel('test'+str(i))

# %%
params = fit_lin_log(df)
# Out:
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in exp
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: invalid value encountered in float_power
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:8: RuntimeWarning: divide by zero encountered in divide
#   logistic = K / logistic_den
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in multiply
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:8: RuntimeWarning: overflow encountered in divide
#   logistic = K / logistic_den
# /var/folders/j5/gzgbj85d7fl1z1qxpqp965kc0000gq/T/ipykernel_36817/1839126831.py:7: RuntimeWarning: overflow encountered in float_power
#   logistic_den = np.float_power(1 + Q * np.exp(-B * x), 1 / nu)

# %%
plot_fit(df, )
# Out:
# [<Axes: >, <Axes: >, <Axes: >, <Axes: >]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 plot_fit([1,2,3,4], 'a')
#
# Cell In[191], line 6, in plot_fit(params, func)
#       4 print(fig.axes)
#       5 for i in range(len(fig.axes)):
# ----> 6     ax[i].set_xlabel('test'+str(i))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_xlabel'
